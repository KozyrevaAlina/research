# %%
##################
from dataset.preparation import convert_type, convert_to_gigital_target
from dataset.preprocessing import prepare_dataset
import pandas as pd
import numpy as np
from sklearn.utils import resample

from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
csv = '/Users/alinakozyreva/Documents/MIPT/3_семестр/ВКР/datasets/CIC_IOT_Dataset2023/csv/part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv'

# %%
df = pd.read_csv(csv)
df = convert_to_gigital_target(df, classification_type='group')
df = convert_type(df)

# %%
MAX_SIZE = 250_000

# %%
trainloaders, validationloaders, testloader = prepare_dataset(df, 
                                                              mode='HALF_BENIGN',  #'STRATIFIED' 'SINGLE_ATTACK' 'RANDOM' 'EXCLUDE_SINGLE_ATTACK' 'HALF_BENIGN'
                                                              normalization='StandardScaler',
                                                              feature_extractor=None,
                                                              num_features=46,
                                                              num_partitions=10,
                                                              max_partitions_size=MAX_SIZE,
                                                              batch_size=64,
                                                              val_ratio=0.2
)

# %%
from collections import Counter
from matplotlib import pyplot as plt

print(Counter(df['label']))
data = Counter(df['label'])
print(sum(data.values()))

labels, values = zip(*data.items())

fig, ax = plt.subplots()
ax.bar(labels, values)

ax.set_xlabel('тип вторжения')
ax.set_ylabel('Количество')
ax.set_title('Распределение вторжений')

plt.show()
# Out:
# Counter({1: 325396, 2: 77652, 3: 25516, 0: 10687, 5: 4703, 4: 3340, 6: 231, 7: 113})
# 447638

# %% [markdown]
# # Preparing the experiment

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# We'll be training the model in a Federated setting. In order to do that, we need to define two functions:
#
# * `train()` that will train the model given a dataloader.
# * `test()` that will be used to evaluate the performance of the model on held-out data, e.g., a training set.

# %%
class Net(nn.Module): 
    def __init__(self, 
                 num_classes: int=8): # input_size = 46 number of features
        super(Net, self).__init__()
        self.lstm = nn.LSTM(
            input_size=46,
            hidden_size=32,
            bidirectional=True,
        )
       
        self.fc = nn.Linear(32 * 2, num_classes)

    def forward(self, x):
        x = x.transpose(0, 1) # (sequence_length, batch_size, input_size)
        r_out, (h_n, h_c) = self.lstm(x)
        r_out = r_out[-1]  
        model = self.fc(r_out) 
        return model

# %%
net = Net(num_classes=8)

# %%
print(net)
print(net.parameters)
total = sum([param.nelement() for param in net.parameters()])
print("Number of parameter: %.2fM" % (total / 1e6))
# Out:
# Net(
#   (lstm): LSTM(46, 32, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=8, bias=True)
# )
# <bound method Module.parameters of Net(
#   (lstm): LSTM(46, 32, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=8, bias=True)
# )>
# Number of parameter: 0.02M

# %%
def train(net, trainloader, optimizer, epochs, device):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    net.train()
    net.to(device)

    for _ in range(epochs):
        for features, labels in trainloader:
            features, labels = features.to(device), labels.to(device)
            features = features.view(-1, 1, 46).float() # for transformation
            labels = labels.long() ######
            optimizer.zero_grad()
            outputs = net(features)
            outputs = outputs.float() ######
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    return net


def test(net, testloader, device):
    """Validate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, loss = 0, 0.0

    predicts = []
    all_labels = []

    net.eval()
    net.to(device)
    with torch.no_grad():
        for features, labels in testloader:
            features, labels = features.to(device), labels.to(device)
            features = features.view(-1, 1, 46).float()
            labels = labels.long() ######
            outputs = net(features)
            outputs = outputs.float() ######
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()

            #####
            # for metrics   
            # Collect predictions and true labels for later use in calculating metrics
            predicts += predicted.tolist()
            all_labels += labels.cpu().numpy().tolist()
    # accuracy = correct / len(testloader.dataset)
    accuracy = accuracy_score(all_labels, predicts)
    precision = precision_score(all_labels, predicts, average='weighted', zero_division=1)
    recall = recall_score(all_labels, predicts, average='weighted', zero_division=1)
    f1 = f1_score(all_labels, predicts, average='weighted')
    
    return loss, accuracy, precision, recall, f1

# %%
import flwr as fl

# %% [markdown]
# Now let's defice our Flower Client class:

# %%
from collections import OrderedDict
from typing import Dict, List, Tuple

import torch
from flwr.common import NDArrays, Scalar


class FlowerClient(fl.client.NumPyClient):
    def __init__(self, trainloader, vallodaer) -> None:
        super().__init__()

        self.trainloader = trainloader
        self.valloader = vallodaer
        self.model = Net(num_classes=8)
        # Determine device
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)  # send model to device

    def set_parameters(self, parameters):
        """With the model paramters received from the server,
        overwrite the uninitialise model in this class with them."""

        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        # now replace the parameters
        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self, config: Dict[str, Scalar]):
        """Extract all model parameters and conver them to a list of
        NumPy arryas. The server doesn't work with PyTorch/TF/etc."""
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def fit(self, parameters, config):
        """This method train the model using the parameters sent by the
        server on the dataset of this client. At then end, the parameters
        of the locally trained model are communicated back to the server"""

        # copy parameters sent by the server into client's local model
        self.set_parameters(parameters)

        # read from config
        lr, epochs = config["lr"], config["epochs"]

        # Define the optimizer
        # optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=0.9)
        optim = torch.optim.Adam(self.model.parameters(), lr=lr)
        # do local training
        train(self.model, self.trainloader, optim, epochs=epochs, device=self.device)

        # return the model parameters to the server as well as extra info (number of training examples in this case)
        return self.get_parameters({}), len(self.trainloader), {}

    def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]):
        """Evaluate the model sent by the server on this client's
        local validation set. Then return performance metrics."""

        self.set_parameters(parameters)
        loss, accuracy, precision, recall, f1 = test(self.model, self.valloader, device=self.device)
        # send statistics back to the server
        return float(loss), len(self.valloader), {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

# %%
def get_evaluate_fn(testloader):
    """This is a function that returns a function. The returned
    function (i.e. `evaluate_fn`) will be executed by the strategy
    at the end of each round to evaluate the stat of the global
    model."""

    def evaluate_fn(server_round: int, parameters, config):
        """This function is executed by the strategy it will instantiate
        a model and replace its parameters with those from the global model.
        The, the model will be evaluate on the test set"""

        model = Net(num_classes=8)

        # Determine device
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        model.to(device)  # send model to device

        # set parameters to the model
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)

        # call test
        loss, accuracy, precision, recall, f1 = test(model, testloader, device)
        return loss, {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

    return evaluate_fn


# now we can define the strategy
# strategy = fl.server.strategy.FedAvg(
#     fraction_fit=0.1,
#     fraction_evaluate=0.1,
#     min_available_clients=100,
#     evaluate_fn=get_evaluate_fn(testloader), # Even this is not required
# )

# %%
from flwr.common import Metrics


def fit_config(server_round: int) -> Dict[str, Scalar]:
    """Return a configuration with static batch size and (local) epochs."""
    config = {
        "epochs": 1,  # Number of local epochs done by clients
        "lr": 0.008, #0.01,  # Learning rate to use by clients during fit()
    }
    return config


def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    """Aggregation function for (federated) evaluation metrics, i.e. those returned by
    the client's evaluate() method."""
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %% [markdown]
# Now we can define our strategy:

# %%
# strategy = fl.server.strategy.FedAvg(
#     fraction_fit=0.5,  # Sample 10% of available clients for training
#     fraction_evaluate=0.1,  # Sample 5% of available clients for evaluation
#     min_fit_clients=5,  # Never sample less than 10 clients for training
#     min_evaluate_clients=4,  # Never sample less than 5 clients for evaluation
#     min_available_clients=int(
#         7
#     ),  # Wait until at least 75 clients are available
#     on_fit_config_fn=fit_config,
#     evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
#     evaluate_fn=get_evaluate_fn(testloader),  # global evaluation function
# )

# доступны все
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1,  # Sample 10% of available clients for training
    fraction_evaluate=0.2,  # Sample 5% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=int(
        10
    ),  # Wait until at least 75 clients are available
    on_fit_config_fn=fit_config,
    evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
    evaluate_fn=get_evaluate_fn(testloader),  # global evaluation function
)

# %% [markdown]
# So far we have:
# * created the dataset partitions (one for each client)
# * defined the client class
# * decided on a strategy to use
#
# Now we just need to launch the Flower FL experiment... not so fast! just one final function: let's create another callback that the Simulation Engine will use in order to span VirtualClients. As you can see this is really simple: construct a FlowerClient object, assigning each their own data partition.

# %%
def generate_client_fn(trainloaders, valloaders):
    def client_fn(cid: str):
        """Returns a FlowerClient containing the cid-th data partition"""

        return FlowerClient(
            trainloader=trainloaders[int(cid)], vallodaer=valloaders[int(cid)]
        )

    return client_fn


client_fn_callback = generate_client_fn(trainloaders, validationloaders)

# %% [markdown]
# Now we are ready to launch the FL experiment using Flower simulation:

# %%
# With a dictionary, you tell Flower's VirtualClientEngine that each
# client needs exclusive access to these many resources in order to run
client_resources = {"num_cpus": 1, "num_gpus": 0.0}

history = fl.simulation.start_simulation(
    client_fn=client_fn_callback,  # a callback to construct a client
    num_clients=10,  # total number of clients in the experiment
    config=fl.server.ServerConfig(num_rounds=10),  # let's run for 10 rounds
    strategy=strategy,  # the strategy that will orchestrate the whole FL pipeline
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-12-07 02:45:59,624 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-12-07 02:46:04,884	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-12-07 02:46:08,338 | app.py:213 | Flower VCE: Ray initialized with resources: {'memory': 3306926900.0, 'object_store_memory': 1653463449.0, 'node:__internal_head__': 1.0, 'node:127.0.0.1': 1.0, 'CPU': 8.0}
# INFO flwr 2023-12-07 02:46:08,344 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2023-12-07 02:46:08,347 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-12-07 02:46:08,398 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO flwr 2023-12-07 02:46:08,400 | server.py:89 | Initializing global parameters
# INFO flwr 2023-12-07 02:46:08,401 | server.py:276 | Requesting initial parameters from one random client
# (raylet) [2023-12-07 02:46:13,815 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21583233024; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-07 02:46:21,743 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2023-12-07 02:46:21,748 | server.py:91 | Evaluating initial parameters
# (raylet) [2023-12-07 02:46:23,827 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20982018048; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-07 02:46:24,526 | server.py:94 | initial parameters (loss, other metrics): 1497.2235236167908, {'accuracy': 0.012398355821642391, 'precision': 0.7313241949177792, 'recall': 0.012398355821642391, 'f1': 0.005739235837541384}
# INFO flwr 2023-12-07 02:46:24,527 | server.py:104 | FL starting
# DEBUG flwr 2023-12-07 02:46:24,528 | server.py:222 | fit_round 1: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:46:33,837 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19909545984; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:43,890 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19912765440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:53,966 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19596795904; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:04,015 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19327328256; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:14,071 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19317575680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:24,157 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18239127552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:34,218 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18240708608; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:44,272 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18233393152; capacity: 494384795648. Object creation will fail if spilling is required.ERROR flwr 2023-12-07 02:47:48,266 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
#
# ERROR flwr 2023-12-07 02:47:49,044 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 02:47:54,325 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17165713408; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:48:04,391 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19312705536; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 02:48:13,208 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# (raylet) [2023-12-07 02:48:14,491 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18240036864; capacity: 494384795648. Object creation will fail if spilling is required.ERROR flwr 2023-12-07 02:48:14,616 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# (raylet) [2023-12-07 02:48:24,538 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18241589248; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:48:34,562 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18242547712; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:48:44,612 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17166024704; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 02:48:53,923 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 408, in get_client_result
#     self.process_unordered_future(timeout=timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 392, in process_unordered_future
#     self._return_actor(actor)  # type: ignore
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/actor_pool.py", line 366, in _return_actor
#     self.submit(*self._pending_submits.pop(0))
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 02:48:53,970 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 02:48:54,657 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17167884288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:49:04,705 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17165606912; capacity: 494384795648. Object creation will fail if spilling is required.IOStream.flush timed out
#
# (raylet) [2023-12-07 02:49:14,750 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17161175040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:49:24,818 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17160007680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:49:34,869 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17159716864; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 02:49:35,443 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 414, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 300, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/worker.py", line 2513, in get
#     raise ValueError(
# ValueError: 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
#
# ERROR flwr 2023-12-07 02:49:35,453 | ray_client_proxy.py:146 | 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
# DEBUG flwr 2023-12-07 02:49:35,462 | server.py:236 | fit_round 1 received 6 results and 4 failures
# WARNING flwr 2023-12-07 02:49:35,491 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# INFO flwr 2023-12-07 02:49:39,042 | server.py:125 | fit progress: (1, 227.0691430941224, {'accuracy': 0.8785966401572692, 'precision': 0.8804979870408561, 'recall': 0.8785966401572692, 'f1': 0.8650271985477309}, 194.51042558300833)
# DEBUG flwr 2023-12-07 02:49:39,049 | server.py:173 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:49:44,870 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17170681856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:49:54,886 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17171021824; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:50:04,934 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17150775296; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:50:10,891 | server.py:187 | evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:50:10,897 | server.py:222 | fit_round 2: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:50:14,943 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16098058240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:50:24,982 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17166630912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:50:35,001 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18239770624; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 02:50:36,115 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 02:50:36,181 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-07 02:50:42,587 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# (raylet) [2023-12-07 02:50:45,026 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17162723328; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 02:50:45,632 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-07 02:50:46,580 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 02:50:46,585 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 02:50:55,050 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17162608640; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:51:05,057 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17165844480; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:51:15,095 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17164152832; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:51:25,107 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17164525568; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:51:26,853 | server.py:236 | fit_round 2 received 7 results and 3 failures
# INFO flwr 2023-12-07 02:51:29,520 | server.py:125 | fit progress: (2, 31.59381083678454, {'accuracy': 0.9869761415423108, 'precision': 0.9869490750664072, 'recall': 0.9869761415423108, 'f1': 0.9863414986170537}, 304.98614624999755)
# DEBUG flwr 2023-12-07 02:51:29,521 | server.py:173 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:51:35,115 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17160667136; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:51:44,267 | server.py:187 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:51:44,290 | server.py:222 | fit_round 3: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:51:45,145 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16084623360; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:51:55,177 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17155141632; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:52:05,180 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19302612992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:52:15,216 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19300507648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:52:25,235 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18222657536; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:52:35,257 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18225807360; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:52:45,293 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18223230976; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:52:55,303 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18236051456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:53:05,347 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18234994688; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:53:11,075 | server.py:236 | fit_round 3 received 10 results and 0 failures
# INFO flwr 2023-12-07 02:53:12,231 | server.py:125 | fit progress: (3, 25.290118087665178, {'accuracy': 0.9880931105352515, 'precision': 0.9880750638391443, 'recall': 0.9880931105352515, 'f1': 0.9874572446833657}, 407.69577795799705)
# DEBUG flwr 2023-12-07 02:53:12,232 | server.py:173 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:53:15,406 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18004295680; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:53:20,625 | server.py:187 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:53:20,627 | server.py:222 | fit_round 4: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:53:25,490 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18014085120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:53:35,590 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18239270912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:53:45,683 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18234990592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:53:55,707 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18230943744; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:54:05,386 | server.py:236 | fit_round 4 received 10 results and 0 failures
# (raylet) [2023-12-07 02:54:05,723 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18233360384; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-07 02:54:08,223 | server.py:125 | fit progress: (4, 23.368520652118605, {'accuracy': 0.9883611830935574, 'precision': 0.9889880988433635, 'recall': 0.9883611830935574, 'f1': 0.9876527161500162}, 463.6858764170029)
# DEBUG flwr 2023-12-07 02:54:08,223 | server.py:173 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:54:15,823 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18227359744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:54:25,840 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18226835456; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:54:28,426 | server.py:187 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:54:28,434 | server.py:222 | fit_round 5: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:54:35,859 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18225618944; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:54:45,882 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18222292992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:54:55,889 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18233634816; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:55:05,905 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18236592128; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:55:15,915 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18234265600; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:55:25,965 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18229567488; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:55:35,996 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18235056128; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:55:39,642 | server.py:236 | fit_round 5 received 10 results and 0 failures
# INFO flwr 2023-12-07 02:55:41,905 | server.py:125 | fit progress: (5, 21.681713845871855, {'accuracy': 0.9892882673576981, 'precision': 0.9893234281723189, 'recall': 0.9892882673576981, 'f1': 0.9886450733717762}, 557.366204542006)
# DEBUG flwr 2023-12-07 02:55:41,907 | server.py:173 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:55:46,091 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18242342912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:55:56,122 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18240503808; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:55:58,299 | server.py:187 | evaluate_round 5 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:55:58,303 | server.py:222 | fit_round 6: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:56:06,220 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18242158592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:56:16,242 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18241372160; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:56:26,246 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18239684608; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:56:36,345 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18235981824; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:56:46,400 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18234699776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:56:56,443 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18230693888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:57:06,460 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18226905088; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:57:12,133 | server.py:236 | fit_round 6 received 10 results and 0 failures
# INFO flwr 2023-12-07 02:57:13,914 | server.py:125 | fit progress: (6, 21.945078469463624, {'accuracy': 0.988819140380663, 'precision': 0.9891891801975219, 'recall': 0.988819140380663, 'f1': 0.9883788421065438}, 649.3738896249997)
# DEBUG flwr 2023-12-07 02:57:13,915 | server.py:173 | evaluate_round 6: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:57:16,474 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18238459904; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:57:26,482 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17166057472; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:57:32,006 | server.py:187 | evaluate_round 6 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:57:32,015 | server.py:222 | fit_round 7: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:57:36,498 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17161977856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:57:46,543 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17162084352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:57:56,573 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17158987776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:58:06,594 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17161629696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:58:16,622 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17160392704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:58:26,629 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17162858496; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:58:36,663 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17157881856; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:58:44,845 | server.py:236 | fit_round 7 received 10 results and 0 failures
# (raylet) [2023-12-07 02:58:46,680 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17156583424; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-07 02:58:47,263 | server.py:125 | fit progress: (7, 20.023369988266495, {'accuracy': 0.9895004914663569, 'precision': 0.9896954780615389, 'recall': 0.9895004914663569, 'f1': 0.9890650450753941}, 742.7209912079998)
# DEBUG flwr 2023-12-07 02:58:47,265 | server.py:173 | evaluate_round 7: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:58:56,717 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17157832704; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:59:05,107 | server.py:187 | evaluate_round 7 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 02:59:05,111 | server.py:222 | fit_round 8: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 02:59:06,755 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17154211840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:59:16,757 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17152032768; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:59:26,803 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17150373888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:59:36,817 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17151840256; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:59:46,835 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16081739776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:59:56,849 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16074600448; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:00:06,857 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16076697600; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 03:00:14,054 | server.py:236 | fit_round 8 received 10 results and 0 failures
# INFO flwr 2023-12-07 03:00:16,606 | server.py:125 | fit progress: (8, 20.03593131127127, {'accuracy': 0.9895675096059333, 'precision': 0.9891116825974197, 'recall': 0.9895675096059333, 'f1': 0.989054200411507}, 832.0625302080007)
# DEBUG flwr 2023-12-07 03:00:16,607 | server.py:173 | evaluate_round 8: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 03:00:16,864 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16072364032; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:00:26,891 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20360433664; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 03:00:35,645 | server.py:187 | evaluate_round 8 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 03:00:35,651 | server.py:222 | fit_round 9: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 03:00:36,910 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19295903744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:00:46,938 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19295244288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:00:56,957 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19298258944; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:01:06,971 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19295690752; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:01:16,992 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19296980992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:01:27,034 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19309199360; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:01:37,046 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19307859968; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 03:01:37,491 | server.py:236 | fit_round 9 received 10 results and 0 failures
# INFO flwr 2023-12-07 03:01:39,798 | server.py:125 | fit progress: (9, 19.38628260216501, {'accuracy': 0.9899137699937449, 'precision': 0.9899069699857119, 'recall': 0.9899137699937449, 'f1': 0.9894482722838895}, 915.2527426669985)
# DEBUG flwr 2023-12-07 03:01:39,800 | server.py:173 | evaluate_round 9: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 03:01:47,051 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19303354368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:01:57,060 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19298963456; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 03:01:57,945 | server.py:187 | evaluate_round 9 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 03:01:57,951 | server.py:222 | fit_round 10: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 03:02:07,091 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19307655168; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:02:17,117 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19305582592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:02:27,118 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19303276544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:02:37,146 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19300773888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:02:47,163 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18228035584; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:02:57,169 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18240643072; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 03:03:06,544 | server.py:236 | fit_round 10 received 10 results and 0 failures
# (raylet) [2023-12-07 03:03:07,182 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18235392000; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-07 03:03:09,653 | server.py:125 | fit progress: (10, 19.781281036295695, {'accuracy': 0.9898020730944509, 'precision': 0.9898046588078891, 'recall': 0.9898020730944509, 'f1': 0.9892966163705619}, 1005.1055390830006)
# DEBUG flwr 2023-12-07 03:03:09,660 | server.py:173 | evaluate_round 10: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 03:03:17,190 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19304726528; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:03:27,210 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19304071168; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 03:03:31,350 | server.py:187 | evaluate_round 10 received 5 results and 0 failures
# INFO flwr 2023-12-07 03:03:31,355 | server.py:153 | FL finished in 1026.8079710830061
# INFO flwr 2023-12-07 03:03:31,367 | app.py:226 | app_fit: losses_distributed [(1, 279.2211870716803), (2, 38.15617729677143), (3, 30.370602032052943), (4, 27.97917843910071), (5, 25.555877919843173), (6, 26.585458898065855), (7, 23.254335945190558), (8, 21.906614275609186), (9, 23.06125549349855), (10, 23.393203962873773)]
# INFO flwr 2023-12-07 03:03:31,370 | app.py:227 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-12-07 03:03:31,371 | app.py:228 | app_fit: metrics_distributed {'accuracy': [(1, 0.8799766692619749), (2, 0.9865714982447777), (3, 0.9881689664376435), (4, 0.9885843175054975), (5, 0.9891428497318806), (6, 0.9886793535040226), (7, 0.9899589538173696), (8, 0.9897261353818856), (9, 0.99018525782462), (10, 0.9899891808601903)]}
# INFO flwr 2023-12-07 03:03:31,373 | app.py:229 | app_fit: losses_centralized [(0, 1497.2235236167908), (1, 227.0691430941224), (2, 31.59381083678454), (3, 25.290118087665178), (4, 23.368520652118605), (5, 21.681713845871855), (6, 21.945078469463624), (7, 20.023369988266495), (8, 20.03593131127127), (9, 19.38628260216501), (10, 19.781281036295695)]
# INFO flwr 2023-12-07 03:03:31,374 | app.py:230 | app_fit: metrics_centralized {'accuracy': [(0, 0.012398355821642391), (1, 0.8785966401572692), (2, 0.9869761415423108), (3, 0.9880931105352515), (4, 0.9883611830935574), (5, 0.9892882673576981), (6, 0.988819140380663), (7, 0.9895004914663569), (8, 0.9895675096059333), (9, 0.9899137699937449), (10, 0.9898020730944509)], 'precision': [(0, 0.7313241949177792), (1, 0.8804979870408561), (2, 0.9869490750664072), (3, 0.9880750638391443), (4, 0.9889880988433635), (5, 0.9893234281723189), (6, 0.9891891801975219), (7, 0.9896954780615389), (8, 0.9891116825974197), (9, 0.9899069699857119), (10, 0.9898046588078891)], 'recall': [(0, 0.012398355821642391), (1, 0.8785966401572692), (2, 0.9869761415423108), (3, 0.9880931105352515), (4, 0.9883611830935574), (5, 0.9892882673576981), (6, 0.988819140380663), (7, 0.9895004914663569), (8, 0.9895675096059333), (9, 0.9899137699937449), (10, 0.9898020730944509)], 'f1': [(0, 0.005739235837541384), (1, 0.8650271985477309), (2, 0.9863414986170537), (3, 0.9874572446833657), (4, 0.9876527161500162), (5, 0.9886450733717762), (6, 0.9883788421065438), (7, 0.9890650450753941), (8, 0.989054200411507), (9, 0.9894482722838895), (10, 0.9892966163705619)]}

# %%
from matplotlib import pyplot as plt


print(f"{history.metrics_centralized = }")

global_accuracy_centralised = history.metrics_centralized["accuracy"]
global_recall_centralised = history.metrics_centralized["recall"]
global_precision_centralised = history.metrics_centralized["precision"]
global_f1_centralised = history.metrics_centralized["f1"]


round = [data[0] for data in global_accuracy_centralised]
acc = [100.0 * data[1] for data in global_accuracy_centralised]
recall = [100.0 * data[1] for data in global_recall_centralised]
precision = [100.0 * data[1] for data in global_precision_centralised]
f1 = [100.0 * data[1] for data in global_f1_centralised]

plt.plot(round, acc, label='Accuracy')
plt.plot(round, recall, label='Recall')
plt.plot(round, f1, label='F1 Score')
plt.plot(round, precision, label='Precision')

plt.grid()
plt.xlabel('Round')
plt.ylabel('Percentage (%)')
plt.legend()
plt.show()


print('Size; Precision; Recall; F1; Accuracy;')
print(f'{MAX_SIZE}; {precision[10]}; {recall[10]}; {f1[10]}; {acc[10]};')
# Out:
# history.metrics_centralized = {'accuracy': [(0, 0.012398355821642391), (1, 0.8785966401572692), (2, 0.9869761415423108), (3, 0.9880931105352515), (4, 0.9883611830935574), (5, 0.9892882673576981), (6, 0.988819140380663), (7, 0.9895004914663569), (8, 0.9895675096059333), (9, 0.9899137699937449), (10, 0.9898020730944509)], 'precision': [(0, 0.7313241949177792), (1, 0.8804979870408561), (2, 0.9869490750664072), (3, 0.9880750638391443), (4, 0.9889880988433635), (5, 0.9893234281723189), (6, 0.9891891801975219), (7, 0.9896954780615389), (8, 0.9891116825974197), (9, 0.9899069699857119), (10, 0.9898046588078891)], 'recall': [(0, 0.012398355821642391), (1, 0.8785966401572692), (2, 0.9869761415423108), (3, 0.9880931105352515), (4, 0.9883611830935574), (5, 0.9892882673576981), (6, 0.988819140380663), (7, 0.9895004914663569), (8, 0.9895675096059333), (9, 0.9899137699937449), (10, 0.9898020730944509)], 'f1': [(0, 0.005739235837541384), (1, 0.8650271985477309), (2, 0.9863414986170537), (3, 0.9874572446833657), (4, 0.9876527161500162), (5, 0.9886450733717762), (6, 0.9883788421065438), (7, 0.9890650450753941), (8, 0.989054200411507), (9, 0.9894482722838895), (10, 0.9892966163705619)]}
# Size; Precision; Recall; F1; Accuracy;
# 250000; 98.98046588078891; 98.98020730944509; 98.92966163705618; 98.98020730944509;
# (raylet) [2023-12-07 03:03:37,215 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19299135488; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:03:47,240 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20370001920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:03:57,268 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20366999552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:04:07,276 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20365012992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:04:17,373 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20364451840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:04:27,380 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20361297920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:04:37,417 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357713920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:04:47,422 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20362752000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:04:57,429 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20359569408; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:05:07,444 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357275648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:05:17,468 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20358909952; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:05:27,490 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20363923456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:05:37,494 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20361142272; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:05:47,500 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20361351168; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:05:57,545 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20359262208; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:06:07,563 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20358238208; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:06:17,584 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20359319552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:06:27,597 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20356567040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:06:37,611 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20353130496; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:06:47,618 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357963776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:06:57,634 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20351762432; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:07:07,645 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357988352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:07:17,739 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20353572864; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:07:27,752 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20351655936; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:07:37,758 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20362588160; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:07:47,785 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20368642048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:07:57,803 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20374605824; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:08:07,822 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20374339584; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:08:17,830 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20369412096; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:08:27,841 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20366135296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:08:37,857 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20372213760; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:08:47,875 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20367728640; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:08:57,882 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20365414400; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:09:07,900 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20141084672; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:09:17,914 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20146241536; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:09:27,927 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20371169280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:09:37,954 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20365152256; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:09:47,981 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20364918784; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:09:58,000 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20358438912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:10:08,010 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357890048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:10:18,019 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20354244608; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:10:28,028 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20353261568; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:10:38,032 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357447680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:10:48,059 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20354011136; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:10:58,072 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20351447040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:11:08,083 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20348424192; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:11:18,096 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20344815616; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:11:28,180 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20337836032; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:11:38,187 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20334997504; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:11:48,204 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20347924480; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:11:58,304 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20345085952; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:12:08,309 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20342681600; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:12:18,328 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20340391936; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:12:28,331 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20337438720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:12:38,348 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20336926720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:12:48,367 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20333117440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:12:58,467 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20345032704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:13:08,480 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20342538240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:13:18,497 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20337729536; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:13:28,532 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20352409600; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:13:38,545 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20350197760; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:13:48,566 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20347371520; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:13:58,570 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20359753728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:14:08,573 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20354748416; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:14:18,584 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20349595648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:14:28,605 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20350509056; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:14:38,628 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20350795776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:14:48,643 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20367233024; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:14:58,654 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20362485760; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:15:08,669 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20358086656; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:15:18,676 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357402624; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:15:28,685 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20351938560; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:15:38,691 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20357079040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:15:48,703 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20351930368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:15:58,802 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20348125184; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:16:08,842 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20346032128; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:16:18,870 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20342251520; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:16:28,899 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20347240448; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:16:38,925 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20341932032; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:16:48,946 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20336803840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:16:59,047 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20337074176; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:17:09,049 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20342964224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:17:19,055 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20335775744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:17:29,155 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20325765120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:17:39,159 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20321280000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:17:49,259 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20320538624; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:17:59,260 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20338966528; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:18:09,272 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20333129728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:18:19,303 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20329402368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:18:29,316 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20320923648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:18:39,349 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20338913280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:18:49,359 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20342796288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:18:59,360 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20339372032; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:19:09,380 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20335562752; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:19:19,477 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20333629440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:19:29,483 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20337905664; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:19:39,492 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20332843008; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:19:49,516 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20331610112; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:19:59,519 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20325888000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:20:09,526 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20321714176; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:20:19,536 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20323057664; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:20:29,562 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20323663872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:20:39,581 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20097482752; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:20:49,679 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20321021952; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:20:59,685 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20299714560; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:21:09,693 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20307243008; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:21:19,696 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20304216064; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:21:29,800 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20297068544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:21:39,897 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20295426048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:21:49,995 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20303757312; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:22:00,096 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20301119488; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:22:10,116 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20296204288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:22:20,125 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20293349376; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:22:30,145 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20291076096; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:22:40,170 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20294610944; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:22:50,200 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20295794688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:23:00,233 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20301885440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:23:10,251 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20299055104; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:23:20,348 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20300042240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:23:30,447 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20304166912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:23:40,548 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20310335488; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:23:50,643 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20306849792; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:24:00,643 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20321566720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:24:10,649 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20320612352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:24:20,655 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20321484800; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:24:30,662 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20320673792; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:24:40,672 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20325662720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:24:50,675 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20324597760; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:25:00,682 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20323950592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:25:10,692 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20316999680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:25:20,793 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20312784896; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:25:30,801 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20316274688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:25:40,809 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20316688384; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:25:50,903 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20313739264; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:26:00,905 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20309651456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:26:10,918 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20308074496; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:26:20,929 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21651820544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:26:30,948 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21649924096; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:26:41,014 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21645578240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:26:51,049 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21643218944; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:27:01,073 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21641613312; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:27:11,141 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19488444416; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:27:21,158 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18737721344; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:27:31,259 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18418024448; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:27:41,269 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17342164992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:27:51,292 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16268582912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:28:01,307 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16279961600; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:28:11,392 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 16277045248; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:28:21,409 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19494146048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:28:31,417 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19501428736; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:28:41,441 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19497390080; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:28:51,466 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18421907456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:29:01,478 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19494858752; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:29:11,576 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18421190656; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:29:21,678 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19494309888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:29:31,688 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19490222080; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:29:41,697 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19489554432; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:29:51,700 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19486584832; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:30:01,798 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19483947008; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:30:11,898 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19503218688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:30:21,993 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19499966464; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:30:32,000 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19503579136; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:30:42,094 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19498696704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:30:52,098 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19494264832; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:31:02,101 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19489075200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:31:12,105 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19488055296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:31:22,113 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19484065792; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:31:32,116 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19486158848; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:31:42,125 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19488317440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:31:52,132 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19486089216; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:32:02,144 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19456274432; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:32:12,156 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19246243840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:32:22,175 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19247628288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:32:32,274 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19252727808; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:32:42,280 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19486167040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:32:52,377 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19484430336; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:33:02,393 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19491491840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:33:12,409 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19498246144; capacity: 494384795648. Object creation will fail if spilling is required.
# ...
# (raylet) [2023-12-07 03:38:23,664 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19479453696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:38:33,668 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19479224320; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:38:43,730 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19485257728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:38:53,750 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19478691840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:03,775 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18414477312; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:13,841 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19487494144; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:23,932 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19491561472; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:33,950 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19739377664; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:43,951 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19742253056; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:53,986 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19736682496; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:04,003 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19735818240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:14,043 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19734347776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:24,083 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18654621696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:34,172 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19731206144; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:44,202 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19728392192; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:54,213 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19725307904; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:04,225 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19729702912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:14,248 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19730235392; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:24,257 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19727511552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:34,313 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19727454208; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:44,376 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18645561344; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:54,404 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18646798336; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:04,458 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19722620928; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:14,500 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19725762560; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:24,515 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19724267520; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:34,531 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19720867840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:44,555 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18641809408; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:54,573 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18647801856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:04,640 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18657157120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:14,701 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18659217408; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:24,772 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17585733632; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:34,814 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17585602560; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:44,876 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 17585254400; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:54,911 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 18654756864; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:04,939 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19727056896; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:14,944 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19730460672; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:24,968 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19740332032; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:34,986 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19749892096; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:44,989 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19744215040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:55,074 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19738714112; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:05,087 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20810211328; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:15,090 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19736735744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:25,095 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19741069312; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:35,098 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19746127872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:45,102 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19744505856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:55,114 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19742175232; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:05,127 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20812652544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:15,136 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19740041216; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:25,153 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20814909440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:35,154 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19741044736; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:45,253 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19738136576; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:55,273 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19733618688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:05,284 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20806414336; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:15,296 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19730178048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:25,311 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 19729276928; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:35,322 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20808372224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:45,352 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20802285568; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:55,391 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20799336448; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:48:05,489 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 20809891840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:48:15,492 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21881122816; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:48:25,498 E 40244 2332692] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_02-45-59_806820_39999 is over 95% full, available space: 21873983488; capacity: 494384795648. Object creation will fail if spilling is required.
