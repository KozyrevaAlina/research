# %%
##################
from dataset.preparation import convert_type, convert_to_gigital_target
from dataset.preprocessing import prepare_dataset
import pandas as pd
import numpy as np
from sklearn.utils import resample

from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
csv = '/Users/alinakozyreva/Documents/MIPT/3_семестр/ВКР/datasets/CIC_IOT_Dataset2023/csv/part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv'

# %%
df = pd.read_csv(csv)
df = convert_to_gigital_target(df, classification_type='group')
df = convert_type(df)

# %%
MAX_SIZE = 400_000

# %%
trainloaders, validationloaders, testloader = prepare_dataset(df, 
                                                              mode='STRATIFIED',  #'STRATIFIED' 'SINGLE_ATTACK' 'RANDOM' 'EXCLUDE_SINGLE_ATTACK' 'HALF_BENIGN'
                                                              normalization='StandardScaler',
                                                              feature_extractor=None,
                                                              num_features=46,
                                                              num_partitions=10,
                                                              max_partitions_size=MAX_SIZE,
                                                              batch_size=64,
                                                              val_ratio=0.2
)

# %%
from collections import Counter
from matplotlib import pyplot as plt

print(Counter(df['label']))
data = Counter(df['label'])
print(sum(data.values()))

labels, values = zip(*data.items())

fig, ax = plt.subplots()
ax.bar(labels, values)

ax.set_xlabel('тип вторжения')
ax.set_ylabel('Количество')
ax.set_title('Распределение вторжений')

plt.show()
# Out:
# Counter({1: 325396, 2: 77652, 3: 25516, 0: 10687, 5: 4703, 4: 3340, 6: 231, 7: 113})
# 447638

# %% [markdown]
# # Preparing the experiment

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# We'll be training the model in a Federated setting. In order to do that, we need to define two functions:
#
# * `train()` that will train the model given a dataloader.
# * `test()` that will be used to evaluate the performance of the model on held-out data, e.g., a training set.

# %%
class Net(nn.Module): 
    def __init__(self, 
                 num_classes: int=8): # input_size = 46 number of features
        super(Net, self).__init__()
        self.lstm = nn.LSTM(
            input_size=46,
            hidden_size=32,
            bidirectional=True,
        )
       
        self.fc = nn.Linear(32 * 2, num_classes)

    def forward(self, x):
        x = x.transpose(0, 1) # (sequence_length, batch_size, input_size)
        r_out, (h_n, h_c) = self.lstm(x)
        r_out = r_out[-1]  
        model = self.fc(r_out) 
        return model

# %%
net = Net(num_classes=8)

# %%
print(net)
print(net.parameters)
total = sum([param.nelement() for param in net.parameters()])
print("Number of parameter: %.2fM" % (total / 1e6))
# Out:
# Net(
#   (lstm): LSTM(46, 32, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=8, bias=True)
# )
# <bound method Module.parameters of Net(
#   (lstm): LSTM(46, 32, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=8, bias=True)
# )>
# Number of parameter: 0.02M

# %%
def train(net, trainloader, optimizer, epochs, device):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    net.train()
    net.to(device)

    for _ in range(epochs):
        for features, labels in trainloader:
            features, labels = features.to(device), labels.to(device)
            features = features.view(-1, 1, 46).float() # for transformation
            labels = labels.long() ######
            optimizer.zero_grad()
            outputs = net(features)
            outputs = outputs.float() ######
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    return net


def test(net, testloader, device):
    """Validate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, loss = 0, 0.0

    predicts = []
    all_labels = []

    net.eval()
    net.to(device)
    with torch.no_grad():
        for features, labels in testloader:
            features, labels = features.to(device), labels.to(device)
            features = features.view(-1, 1, 46).float()
            labels = labels.long() ######
            outputs = net(features)
            outputs = outputs.float() ######
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()

            #####
            # for metrics   
            # Collect predictions and true labels for later use in calculating metrics
            predicts += predicted.tolist()
            all_labels += labels.cpu().numpy().tolist()
    # accuracy = correct / len(testloader.dataset)
    accuracy = accuracy_score(all_labels, predicts)
    precision = precision_score(all_labels, predicts, average='weighted', zero_division=1)
    recall = recall_score(all_labels, predicts, average='weighted', zero_division=1)
    f1 = f1_score(all_labels, predicts, average='weighted')
    
    return loss, accuracy, precision, recall, f1

# %%
import flwr as fl

# %% [markdown]
# Now let's defice our Flower Client class:

# %%
from collections import OrderedDict
from typing import Dict, List, Tuple

import torch
from flwr.common import NDArrays, Scalar


class FlowerClient(fl.client.NumPyClient):
    def __init__(self, trainloader, vallodaer) -> None:
        super().__init__()

        self.trainloader = trainloader
        self.valloader = vallodaer
        self.model = Net(num_classes=8)
        # Determine device
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)  # send model to device

    def set_parameters(self, parameters):
        """With the model paramters received from the server,
        overwrite the uninitialise model in this class with them."""

        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        # now replace the parameters
        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self, config: Dict[str, Scalar]):
        """Extract all model parameters and conver them to a list of
        NumPy arryas. The server doesn't work with PyTorch/TF/etc."""
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def fit(self, parameters, config):
        """This method train the model using the parameters sent by the
        server on the dataset of this client. At then end, the parameters
        of the locally trained model are communicated back to the server"""

        # copy parameters sent by the server into client's local model
        self.set_parameters(parameters)

        # read from config
        lr, epochs = config["lr"], config["epochs"]

        # Define the optimizer
        # optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=0.9)
        optim = torch.optim.Adam(self.model.parameters(), lr=lr)
        # do local training
        train(self.model, self.trainloader, optim, epochs=epochs, device=self.device)

        # return the model parameters to the server as well as extra info (number of training examples in this case)
        return self.get_parameters({}), len(self.trainloader), {}

    def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]):
        """Evaluate the model sent by the server on this client's
        local validation set. Then return performance metrics."""

        self.set_parameters(parameters)
        loss, accuracy, precision, recall, f1 = test(self.model, self.valloader, device=self.device)
        # send statistics back to the server
        return float(loss), len(self.valloader), {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

# %%
def get_evaluate_fn(testloader):
    """This is a function that returns a function. The returned
    function (i.e. `evaluate_fn`) will be executed by the strategy
    at the end of each round to evaluate the stat of the global
    model."""

    def evaluate_fn(server_round: int, parameters, config):
        """This function is executed by the strategy it will instantiate
        a model and replace its parameters with those from the global model.
        The, the model will be evaluate on the test set """

        model = Net(num_classes=8)

        # Determine device
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        model.to(device)  # send model to device

        # set parameters to the model
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)

        # call test
        loss, accuracy, precision, recall, f1 = test(model, testloader, device)
        return loss, {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

    return evaluate_fn


# now we can define the strategy
# strategy = fl.server.strategy.FedAvg(
#     fraction_fit=0.1,
#     fraction_evaluate=0.1,
#     min_available_clients=100,
#     evaluate_fn=get_evaluate_fn(testloader), # Even this is not required
# )

# %%
from flwr.common import Metrics


def fit_config(server_round: int) -> Dict[str, Scalar]:
    """Return a configuration with static batch size and (local) epochs."""
    config = {
        "epochs": 1,  # Number of local epochs done by clients
        "lr": 0.008, #0.01,  # Learning rate to use by clients during fit()
    }
    return config


def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    """Aggregation function for (federated) evaluation metrics, i.e. those returned by
    the client's evaluate() method."""
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %% [markdown]
# Now we can define our strategy:

# %%
# strategy = fl.server.strategy.FedAvg(
#     fraction_fit=0.5,  # Sample 10% of available clients for training
#     fraction_evaluate=0.1,  # Sample 5% of available clients for evaluation
#     min_fit_clients=5,  # Never sample less than 10 clients for training
#     min_evaluate_clients=4,  # Never sample less than 5 clients for evaluation
#     min_available_clients=int(
#         7
#     ),  # Wait until at least 75 clients are available
#     on_fit_config_fn=fit_config,
#     evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
#     evaluate_fn=get_evaluate_fn(testloader),  # global evaluation function
# )

# доступны все
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1,  # Sample 10% of available clients for training
    fraction_evaluate=0.2,  # Sample 5% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=int(
        10
    ),  # Wait until at least 75 clients are available
    on_fit_config_fn=fit_config,
    evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
    evaluate_fn=get_evaluate_fn(testloader),  # global evaluation function
)

# %% [markdown]
# So far we have:
# * created the dataset partitions (one for each client)
# * defined the client class
# * decided on a strategy to use
#
# Now we just need to launch the Flower FL experiment... not so fast! just one final function: let's create another callback that the Simulation Engine will use in order to span VirtualClients. As you can see this is really simple: construct a FlowerClient object, assigning each their own data partition.

# %%
def generate_client_fn(trainloaders, valloaders):
    def client_fn(cid: str):
        """Returns a FlowerClient containing the cid-th data partition"""

        return FlowerClient(
            trainloader=trainloaders[int(cid)], vallodaer=valloaders[int(cid)]
        )

    return client_fn


client_fn_callback = generate_client_fn(trainloaders, validationloaders)

# %% [markdown]
# Now we are ready to launch the FL experiment using Flower simulation:

# %%
# With a dictionary, you tell Flower's VirtualClientEngine that each
# client needs exclusive access to these many resources in order to run
client_resources = {"num_cpus": 1, "num_gpus": 0.0}

history = fl.simulation.start_simulation(
    client_fn=client_fn_callback,  # a callback to construct a client
    num_clients=10,  # total number of clients in the experiment
    config=fl.server.ServerConfig(num_rounds=10),  # let's run for 10 rounds
    strategy=strategy,  # the strategy that will orchestrate the whole FL pipeline
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-12-07 01:23:19,157 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-12-07 01:23:21,396	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-12-07 01:23:23,084 | app.py:213 | Flower VCE: Ray initialized with resources: {'memory': 3062779086.0, 'node:__internal_head__': 1.0, 'node:127.0.0.1': 1.0, 'CPU': 8.0, 'object_store_memory': 1531389542.0}
# INFO flwr 2023-12-07 01:23:23,089 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2023-12-07 01:23:23,090 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-12-07 01:23:23,116 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO flwr 2023-12-07 01:23:23,117 | server.py:89 | Initializing global parameters
# INFO flwr 2023-12-07 01:23:23,117 | server.py:276 | Requesting initial parameters from one random client
# INFO flwr 2023-12-07 01:23:39,220 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2023-12-07 01:23:39,225 | server.py:91 | Evaluating initial parameters
# INFO flwr 2023-12-07 01:23:40,387 | server.py:94 | initial parameters (loss, other metrics): 1415.0785126686096, {'accuracy': 0.1392078455902064, 'precision': 0.4501361418180754, 'recall': 0.1392078455902064, 'f1': 0.20891780597435755}
# INFO flwr 2023-12-07 01:23:40,388 | server.py:104 | FL starting
# DEBUG flwr 2023-12-07 01:23:40,389 | server.py:222 | fit_round 1: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:23:52,456 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24718614528; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:24:02,462 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23590391808; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:24:12,523 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23586734080; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:24:17,313 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 01:24:18,937 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 01:24:22,539 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24657059840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:24:39,503 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24664965120; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:24:45,693 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# (raylet) [2023-12-07 01:24:49,515 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24662016000; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:24:54,756 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-07 01:25:00,987 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 01:25:06,599 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 01:25:36,487 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24717025280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:25:46,577 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23336177664; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:25:56,671 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23308480512; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:26:06,754 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24379973632; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:26:10,031 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 408, in get_client_result
#     self.process_unordered_future(timeout=timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 392, in process_unordered_future
#     self._return_actor(actor)  # type: ignore
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/actor_pool.py", line 366, in _return_actor
#     self.submit(*self._pending_submits.pop(0))
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 01:26:14,791 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 01:26:16,763 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22228889600; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:26:19,440 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 408, in get_client_result
#     self.process_unordered_future(timeout=timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 392, in process_unordered_future
#     self._return_actor(actor)  # type: ignore
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/actor_pool.py", line 366, in _return_actor
#     self.submit(*self._pending_submits.pop(0))
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 01:26:19,455 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-07 01:26:21,443 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 414, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 300, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/worker.py", line 2513, in get
#     raise ValueError(
# ValueError: 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
#
# ERROR flwr 2023-12-07 01:26:21,443 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 414, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 300, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/worker.py", line 2513, in get
#     raise ValueError(
# ValueError: 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
#
# ERROR flwr 2023-12-07 01:26:21,444 | ray_client_proxy.py:146 | 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
# ERROR flwr 2023-12-07 01:26:21,444 | ray_client_proxy.py:146 | 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
# DEBUG flwr 2023-12-07 01:26:21,451 | server.py:236 | fit_round 1 received 3 results and 7 failures
# WARNING flwr 2023-12-07 01:26:21,472 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# INFO flwr 2023-12-07 01:26:22,683 | server.py:125 | fit progress: (1, 151.91555256396532, {'accuracy': 0.9069341435081762, 'precision': 0.9095735942344835, 'recall': 0.9069341435081762, 'f1': 0.9005294596353156}, 162.29403849999653)
# DEBUG flwr 2023-12-07 01:26:22,686 | server.py:173 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:26:26,772 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22229651456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:26:36,873 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21152665600; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:26:46,960 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24383389696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:26:57,056 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24380059648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:27:07,180 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24379031552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:27:17,274 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23320489984; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:27:27,283 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23316787200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:27:37,288 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22242430976; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:27:47,308 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21171281920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:28:03,271 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24390385664; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:28:13,301 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23315492864; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:28:23,328 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23316217856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:28:33,340 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23313887232; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:28:43,350 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24391249920; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:28:47,327 | server.py:187 | evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:28:47,331 | server.py:222 | fit_round 2: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:29:00,134 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24390234112; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:29:10,142 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24390053888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:29:20,145 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24384389120; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:29:29,434 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# (raylet) [2023-12-07 01:29:30,238 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23308304384; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:29:38,116 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 01:29:40,244 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22238564352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:29:51,447 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24377475072; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:30:01,499 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23293009920; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:30:01,608 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 408, in get_client_result
#     self.process_unordered_future(timeout=timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 392, in process_unordered_future
#     self._return_actor(actor)  # type: ignore
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/actor_pool.py", line 366, in _return_actor
#     self.submit(*self._pending_submits.pop(0))
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-07 01:30:01,630 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-07 01:30:11,601 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23315423232; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:30:21,603 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22237696000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:30:48,169 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24387174400; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:31:14,213 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24383197184; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:31:32,989 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24381882368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:31:54,175 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24377655296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:32:28,176 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24391131136; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:32:38,265 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24381612032; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-07 01:32:55,499 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 138, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 414, in get_client_result
#     return self._fetch_future_result(cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 300, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/_private/worker.py", line 2513, in get
#     raise ValueError(
# ValueError: 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
#
# ERROR flwr 2023-12-07 01:32:55,506 | ray_client_proxy.py:146 | 'object_refs' must either be an ObjectRef or a list of ObjectRefs.
# DEBUG flwr 2023-12-07 01:32:55,510 | server.py:236 | fit_round 2 received 7 results and 3 failures
# INFO flwr 2023-12-07 01:32:57,075 | server.py:125 | fit progress: (2, 28.65833278768696, {'accuracy': 0.9855799303011349, 'precision': 0.9864854978445747, 'recall': 0.9855799303011349, 'f1': 0.985533831564264}, 556.6823397499975)
# DEBUG flwr 2023-12-07 01:32:57,075 | server.py:173 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:33:04,599 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24381411328; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:33:26,706 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24388349952; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:33:49,107 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24380575744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:34:07,476 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24379412480; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:34:21,051 | server.py:187 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:34:21,055 | server.py:222 | fit_round 3: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:34:26,559 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24384548864; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:34:36,659 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24382517248; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:34:55,952 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24373022720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:35:17,750 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24377274368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:35:44,196 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24371421184; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:36:02,556 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24370053120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:36:25,048 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24375234560; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:36:51,300 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24393728000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:37:13,921 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24392691712; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:37:32,288 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24391610368; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:38:01,670 | server.py:236 | fit_round 3 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:38:02,917 | server.py:125 | fit progress: (3, 21.85236932791304, {'accuracy': 0.9886292556518631, 'precision': 0.9886989792414982, 'recall': 0.9886292556518631, 'f1': 0.9882056722790096}, 862.5132110419945)
# DEBUG flwr 2023-12-07 01:38:02,919 | server.py:173 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:38:13,264 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24390594560; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:38:48,476 | server.py:187 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:38:48,484 | server.py:222 | fit_round 4: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:39:03,722 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24386125824; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:40:52,004 | server.py:236 | fit_round 4 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:40:53,596 | server.py:125 | fit progress: (4, 20.90868588560261, {'accuracy': 0.9888638191403807, 'precision': 0.988854437053204, 'recall': 0.9888638191403807, 'f1': 0.9883235926066346}, 1033.1901147919998)
# DEBUG flwr 2023-12-07 01:40:53,596 | server.py:173 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:41:14,496 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24383791104; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:41:35,408 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24378347520; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:41:43,781 | server.py:187 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:41:43,792 | server.py:222 | fit_round 5: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:41:47,720 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24378830848; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:42:48,771 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24378314752; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:44:02,487 | server.py:236 | fit_round 5 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:44:03,646 | server.py:125 | fit progress: (5, 20.167326465132646, {'accuracy': 0.9894558127066393, 'precision': 0.9893862774829141, 'recall': 0.9894558127066393, 'f1': 0.9889189823201556}, 1223.2394120419995)
# DEBUG flwr 2023-12-07 01:44:03,647 | server.py:173 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:44:18,476 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24376389632; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:44:39,109 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24372129792; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:45:06,964 | server.py:187 | evaluate_round 5 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:45:06,970 | server.py:222 | fit_round 6: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:45:12,636 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24377679872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:46:52,118 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24465846272; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:47:02,214 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24364724224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:47:20,095 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24360554496; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:47:56,595 | server.py:236 | fit_round 6 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:47:57,777 | server.py:125 | fit progress: (6, 19.68215034189052, {'accuracy': 0.9894669823965687, 'precision': 0.989535505943224, 'recall': 0.9894669823965687, 'f1': 0.9888195657388024}, 1457.367823208995)
# DEBUG flwr 2023-12-07 01:47:57,778 | server.py:173 | evaluate_round 6: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:48:00,965 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24361955328; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:48:11,060 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24360284160; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:48:26,913 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24357085184; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:48:58,936 | server.py:187 | evaluate_round 6 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:48:58,940 | server.py:222 | fit_round 7: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:49:01,435 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24366915584; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:50:46,771 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24378888192; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:51:10,591 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24376578048; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:51:25,653 | server.py:236 | fit_round 7 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:51:27,531 | server.py:125 | fit progress: (7, 19.42379941069521, {'accuracy': 0.9895340005361452, 'precision': 0.9895812517460995, 'recall': 0.9895340005361452, 'f1': 0.9890120462537999}, 1667.088430625001)
# DEBUG flwr 2023-12-07 01:51:27,532 | server.py:173 | evaluate_round 7: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:51:31,507 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24371052544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:51:49,797 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24372236288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:52:18,576 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24374022144; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:52:34,961 | server.py:187 | evaluate_round 7 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:52:34,966 | server.py:222 | fit_round 8: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:52:40,676 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24371785728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:53:21,247 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24366530560; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:55:05,982 | server.py:236 | fit_round 8 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:55:07,142 | server.py:125 | fit progress: (8, 19.128444223926635, {'accuracy': 0.9899137699937449, 'precision': 0.989884368682817, 'recall': 0.9899137699937449, 'f1': 0.9893187154971147}, 1886.6963146249982)
# DEBUG flwr 2023-12-07 01:55:07,143 | server.py:173 | evaluate_round 8: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:55:10,399 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24365768704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:55:20,489 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24363520000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:55:32,398 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24369627136; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:56:01,791 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24365481984; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:56:08,402 | server.py:187 | evaluate_round 8 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:56:08,409 | server.py:222 | fit_round 9: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-07 01:57:58,415 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24355975168; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:58:31,966 | server.py:236 | fit_round 9 received 10 results and 0 failures
# INFO flwr 2023-12-07 01:58:33,114 | server.py:125 | fit progress: (9, 19.18679152498953, {'accuracy': 0.9899137699937449, 'precision': 0.9898982761412259, 'recall': 0.9899137699937449, 'f1': 0.989436664970257}, 2092.665232583997)
# DEBUG flwr 2023-12-07 01:58:33,116 | server.py:173 | evaluate_round 9: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 01:58:47,553 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24347447296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 01:59:13,402 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24352956416; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 01:59:20,109 | server.py:187 | evaluate_round 9 received 5 results and 0 failures
# DEBUG flwr 2023-12-07 01:59:20,112 | server.py:222 | fit_round 10: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-12-07 02:01:32,639 | server.py:236 | fit_round 10 received 10 results and 0 failures
# INFO flwr 2023-12-07 02:01:33,814 | server.py:125 | fit progress: (10, 18.915693133720197, {'accuracy': 0.9900031275131802, 'precision': 0.990022862675151, 'recall': 0.9900031275131802, 'f1': 0.9895048192160548}, 2273.362407416993)
# DEBUG flwr 2023-12-07 02:01:33,815 | server.py:173 | evaluate_round 10: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-07 02:01:52,718 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24354066432; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-07 02:02:21,040 | server.py:187 | evaluate_round 10 received 5 results and 0 failures
# INFO flwr 2023-12-07 02:02:21,046 | server.py:153 | FL finished in 2320.594223584005
# INFO flwr 2023-12-07 02:02:21,050 | app.py:226 | app_fit: losses_distributed [(1, 121.98976352065802), (2, 22.060364354751073), (3, 17.102855955218548), (4, 16.533844159524598), (5, 15.472629486020015), (6, 15.219856353085197), (7, 15.124493221047306), (8, 14.13167742199803), (9, 14.331194801251694), (10, 14.15195302052489)]
# INFO flwr 2023-12-07 02:02:21,050 | app.py:227 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-12-07 02:02:21,051 | app.py:228 | app_fit: metrics_distributed {'accuracy': [(1, 0.9067213984529893), (2, 0.9857585658038032), (3, 0.9888246628131021), (4, 0.9888470023177235), (5, 0.9896400547317864), (6, 0.9897908463879813), (7, 0.9897573371310491), (8, 0.9904722012789368), (9, 0.9902376364804111), (10, 0.9903884281366061)]}
# INFO flwr 2023-12-07 02:02:21,051 | app.py:229 | app_fit: losses_centralized [(0, 1415.0785126686096), (1, 151.91555256396532), (2, 28.65833278768696), (3, 21.85236932791304), (4, 20.90868588560261), (5, 20.167326465132646), (6, 19.68215034189052), (7, 19.42379941069521), (8, 19.128444223926635), (9, 19.18679152498953), (10, 18.915693133720197)]
# INFO flwr 2023-12-07 02:02:21,051 | app.py:230 | app_fit: metrics_centralized {'accuracy': [(0, 0.1392078455902064), (1, 0.9069341435081762), (2, 0.9855799303011349), (3, 0.9886292556518631), (4, 0.9888638191403807), (5, 0.9894558127066393), (6, 0.9894669823965687), (7, 0.9895340005361452), (8, 0.9899137699937449), (9, 0.9899137699937449), (10, 0.9900031275131802)], 'precision': [(0, 0.4501361418180754), (1, 0.9095735942344835), (2, 0.9864854978445747), (3, 0.9886989792414982), (4, 0.988854437053204), (5, 0.9893862774829141), (6, 0.989535505943224), (7, 0.9895812517460995), (8, 0.989884368682817), (9, 0.9898982761412259), (10, 0.990022862675151)], 'recall': [(0, 0.1392078455902064), (1, 0.9069341435081762), (2, 0.9855799303011349), (3, 0.9886292556518631), (4, 0.9888638191403807), (5, 0.9894558127066393), (6, 0.9894669823965687), (7, 0.9895340005361452), (8, 0.9899137699937449), (9, 0.9899137699937449), (10, 0.9900031275131802)], 'f1': [(0, 0.20891780597435755), (1, 0.9005294596353156), (2, 0.985533831564264), (3, 0.9882056722790096), (4, 0.9883235926066346), (5, 0.9889189823201556), (6, 0.9888195657388024), (7, 0.9890120462537999), (8, 0.9893187154971147), (9, 0.989436664970257), (10, 0.9895048192160548)]}

# %%
from matplotlib import pyplot as plt


print(f"{history.metrics_centralized = }")

global_accuracy_centralised = history.metrics_centralized["accuracy"]
global_recall_centralised = history.metrics_centralized["recall"]
global_precision_centralised = history.metrics_centralized["precision"]
global_f1_centralised = history.metrics_centralized["f1"]


round = [data[0] for data in global_accuracy_centralised]
acc = [100.0 * data[1] for data in global_accuracy_centralised]
recall = [100.0 * data[1] for data in global_recall_centralised]
precision = [100.0 * data[1] for data in global_precision_centralised]
f1 = [100.0 * data[1] for data in global_f1_centralised]

plt.plot(round, acc, label='Accuracy')
plt.plot(round, recall, label='Recall')
plt.plot(round, f1, label='F1 Score')
plt.plot(round, precision, label='Precision')

plt.grid()
plt.xlabel('Round')
plt.ylabel('Percentage (%)')
plt.legend()
plt.show()

print('Size; Precision; Recall; F1; Accuracy;')
print(f'{MAX_SIZE}; {precision[10]}; {recall[10]}; {f1[10]}; {acc[10]};')
# Out:
# history.metrics_centralized = {'accuracy': [(0, 0.1392078455902064), (1, 0.9069341435081762), (2, 0.9855799303011349), (3, 0.9886292556518631), (4, 0.9888638191403807), (5, 0.9894558127066393), (6, 0.9894669823965687), (7, 0.9895340005361452), (8, 0.9899137699937449), (9, 0.9899137699937449), (10, 0.9900031275131802)], 'precision': [(0, 0.4501361418180754), (1, 0.9095735942344835), (2, 0.9864854978445747), (3, 0.9886989792414982), (4, 0.988854437053204), (5, 0.9893862774829141), (6, 0.989535505943224), (7, 0.9895812517460995), (8, 0.989884368682817), (9, 0.9898982761412259), (10, 0.990022862675151)], 'recall': [(0, 0.1392078455902064), (1, 0.9069341435081762), (2, 0.9855799303011349), (3, 0.9886292556518631), (4, 0.9888638191403807), (5, 0.9894558127066393), (6, 0.9894669823965687), (7, 0.9895340005361452), (8, 0.9899137699937449), (9, 0.9899137699937449), (10, 0.9900031275131802)], 'f1': [(0, 0.20891780597435755), (1, 0.9005294596353156), (2, 0.985533831564264), (3, 0.9882056722790096), (4, 0.9883235926066346), (5, 0.9889189823201556), (6, 0.9888195657388024), (7, 0.9890120462537999), (8, 0.9893187154971147), (9, 0.989436664970257), (10, 0.9895048192160548)]}
# Size; Precision; Recall; F1; Accuracy;
# 400000; 99.0022862675151; 99.00031275131802; 98.95048192160549; 99.00031275131802;
# (raylet) [2023-12-07 02:18:28,902 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24710799360; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:18:38,920 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24420855808; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:18:48,931 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24348213248; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:18:58,941 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24187371520; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:19:08,960 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24185090048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:19:18,980 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24194342912; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:19:28,991 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24193556480; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:19:39,089 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24188502016; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:19:49,108 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24183623680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:19:59,179 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23925514240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:20:09,191 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23932665856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:20:19,193 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23925510144; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:20:29,196 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24221908992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:20:39,198 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24215777280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:20:49,298 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24214093824; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:20:59,395 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24210362368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:21:09,493 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24215269376; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:21:19,589 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24217251840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:21:29,676 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24214245376; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:21:39,773 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24208236544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:21:49,870 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24205897728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:21:59,967 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24201445376; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:22:09,969 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24206594048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:22:19,970 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24202887168; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:22:29,974 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24202694656; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:22:40,076 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24201175040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:22:50,087 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24201232384; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:23:00,091 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24196456448; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:23:10,095 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24204713984; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:23:20,104 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24200548352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:23:30,110 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24201961472; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:23:40,211 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24194383872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:23:50,308 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24192745472; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:24:00,312 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24186912768; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:24:10,408 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24192831488; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:24:20,505 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24200822784; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:24:30,601 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24200015872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:24:40,694 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24197541888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:24:50,789 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24194134016; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:25:00,889 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24200556544; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:25:10,986 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24196349952; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:25:21,077 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24195768320; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:25:31,176 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24202440704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:25:41,272 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24199294976; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:25:51,369 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24195457024; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:26:01,467 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24202776576; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:26:11,561 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24197976064; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:26:21,656 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24192495616; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:26:31,752 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24197988352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:26:41,765 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24194088960; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:26:51,865 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24190750720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:27:01,963 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24202100736; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:27:11,981 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24197382144; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:27:21,985 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24193589248; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:27:32,085 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24192204800; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:27:42,090 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24190775296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:27:52,099 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 24251953152; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:28:02,140 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23173365760; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:28:12,163 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22854254592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:28:22,189 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22597443584; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:28:32,214 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21691752448; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:28:42,257 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21613719552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:28:52,294 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21619810304; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:29:02,340 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21614743552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:29:12,366 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21610102784; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:29:22,454 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21624401920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:29:32,549 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21625528320; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:29:42,580 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21631287296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:29:52,612 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21624360960; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:30:02,663 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21619597312; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:30:12,715 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21617287168; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:30:22,795 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21604945920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:30:32,885 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21607391232; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:30:42,901 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21617303552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:30:52,908 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21613150208; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:31:02,927 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21608775680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:31:12,954 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21605625856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:31:23,018 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21581369344; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:31:33,048 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21596864512; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:31:43,079 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21601628160; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:31:53,081 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21598588928; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:32:03,181 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21595283456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:32:13,197 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21593034752; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:32:23,260 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21589430272; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:32:33,296 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23735103488; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:32:43,364 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23735967744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:32:53,402 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23739707392; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:33:03,437 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734231040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:33:13,479 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23730679808; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:33:23,503 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734538240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:33:33,522 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23744692224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:33:43,580 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23507501056; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:33:53,606 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23508869120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:34:03,631 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23504171008; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:34:13,661 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23499649024; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:34:23,705 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23496814592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:34:33,736 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23496802304; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:34:43,769 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23497240576; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:34:53,791 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23748685824; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:35:03,807 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23746306048; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:35:13,830 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23742111744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:35:23,854 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23745081344; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:35:33,884 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23742296064; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:35:43,900 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23740346368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:35:53,936 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23738028032; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:36:04,035 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23737466880; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:36:14,055 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23731671040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:36:24,107 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23732350976; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:36:34,111 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23731400704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:36:44,122 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734112256; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:36:54,137 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23726194688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:37:04,138 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23725649920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:37:14,169 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23722483712; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:37:24,183 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23727407104; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:37:34,184 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23752265728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:37:44,198 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23749857280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:37:54,209 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23750729728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:38:04,224 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23745843200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:38:14,230 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23745175552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:38:24,232 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23742672896; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:38:34,260 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23739162624; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:38:44,286 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23743934464; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:38:54,320 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23742939136; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:39:04,349 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23744573440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:39:14,384 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23738929152; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:39:24,402 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23731150848; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:39:34,427 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23735013376; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:39:44,451 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23740108800; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:39:54,483 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23743213568; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:40:04,508 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23741853696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:40:14,528 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23739076608; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:40:24,535 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23736741888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:40:34,565 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23733747712; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:40:44,598 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23737360384; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:40:54,608 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734108160; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:41:04,632 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23731232768; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:41:14,653 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23730016256; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:41:24,692 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23724793856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:41:34,732 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23722655744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:41:44,748 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23723057152; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:41:54,795 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23721115648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:42:04,803 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23732129792; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:42:14,818 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734349824; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:42:24,839 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23730003968; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:42:34,937 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734960128; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:42:44,943 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23732424704; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:42:55,039 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23728345088; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:43:05,136 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23725527040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:43:15,141 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23725223936; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:43:25,153 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23726088192; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:43:35,156 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23720312832; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:43:45,165 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23721803776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:43:55,183 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23722115072; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:44:05,208 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23719260160; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:44:15,219 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23724769280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:44:25,224 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23725289472; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:44:35,230 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23720775680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:44:45,253 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23728726016; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:44:55,273 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23721975808; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:45:05,373 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23720960000; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:45:15,472 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23725342720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:45:25,473 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23737757696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:45:35,487 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23734419456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:45:45,527 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 23728111616; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:45:55,577 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22654902272; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:05,600 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 22659665920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:15,629 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21583175680; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:25,650 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20984057856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:35,679 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19913662464; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:45,748 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19911110656; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:46:55,841 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19579056128; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:05,878 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19325857792; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:15,953 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19315855360; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:26,027 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18239119360; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:36,089 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18240671744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:46,152 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 17163468800; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:47:56,209 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 17165705216; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 02:48:06,282 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18241863680; capacity: 494384795648. Object creation will fail if spilling is required.
# ...
# (raylet) [2023-12-07 03:38:25,408 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19479928832; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:38:35,423 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19478646784; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:38:45,502 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19482230784; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:38:55,533 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19479478272; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:05,575 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18411606016; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:15,670 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19493969920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:25,672 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19492368384; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:35,693 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19738116096; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:45,752 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19741872128; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:39:55,757 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19738390528; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:05,771 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19735339008; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:15,821 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19733925888; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:25,829 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18653171712; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:35,927 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19730739200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:45,936 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19727007744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:40:55,950 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19722776576; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:05,967 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19729715200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:15,979 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19730354176; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:25,987 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19725266944; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:36,031 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18649071616; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:46,111 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18645377024; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:41:56,119 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19724603392; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:06,175 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19721932800; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:16,233 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19725774848; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:26,330 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19722727424; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:36,344 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18645364736; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:46,370 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18641862656; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:42:56,382 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18643636224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:06,430 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18657157120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:16,508 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 18659241984; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:26,584 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 17585475584; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:36,611 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 17587249152; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:46,672 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 17584230400; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:43:56,706 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19728343040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:06,732 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19727003648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:16,747 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19730305024; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:26,783 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19743059968; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:36,793 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19748704256; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:46,815 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19744890880; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:44:56,868 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19738804224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:06,884 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20805591040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:16,900 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20806991872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:26,911 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19741515776; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:37,011 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19745894400; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:47,110 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19742801920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:45:57,115 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19740336128; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:07,121 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20811329536; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:17,218 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19738771456; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:27,269 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20814909440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:37,274 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19740893184; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:47,282 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19737325568; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:46:57,303 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19734401024; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:07,311 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20806811648; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:17,325 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 19727773696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:27,338 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20801093632; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:37,352 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20807450624; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:47,386 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20802609152; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:47:57,486 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20799168512; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:48:07,493 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 20809572352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:48:17,506 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21876768768; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-07 03:48:27,507 E 94100 2126828] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-07_01-23-19_263932_93984 is over 95% full, available space: 21874806784; capacity: 494384795648. Object creation will fail if spilling is required.
