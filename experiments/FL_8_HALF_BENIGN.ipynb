# %%
##################
from dataset.preparation import convert_type, convert_to_gigital_target
from dataset.preprocessing import prepare_dataset
import pandas as pd
import numpy as np
from sklearn.utils import resample

from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.model_selection import StratifiedShuffleSplit, train_test_split

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
csv = '/Users/alinakozyreva/Documents/MIPT/3_семестр/ВКР/datasets/CIC_IOT_Dataset2023/csv/part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv'

# %%
df = pd.read_csv(csv)
df = convert_to_gigital_target(df, classification_type='group')
df = convert_type(df)

# %%
trainloaders, validationloaders, testloader = prepare_dataset(df, 
                                                              mode='HALF_BENIGN',  #'STRATIFIED' 'SINGLE_ATTACK' 'RANDOM' 'EXCLUDE_SINGLE_ATTACK' 'HALF_BENIGN'
                                                              normalization='StandardScaler',
                                                              feature_extractor=None,
                                                              num_features=46,
                                                              num_partitions=10,
                                                              max_partitions_size=500_000,
                                                              batch_size=64,
                                                              val_ratio=0.2
)

# %%
from collections import Counter
from matplotlib import pyplot as plt

print(Counter(df['label']))
data = Counter(df['label'])

labels, values = zip(*data.items())

fig, ax = plt.subplots()
ax.bar(labels, values)

ax.set_xlabel('тип вторжения')
ax.set_ylabel('Количество')
ax.set_title('Распределение вторжений')

plt.show()
# Out:
# Counter({1: 325396, 2: 77652, 3: 25516, 0: 10687, 5: 4703, 4: 3340, 6: 231, 7: 113})

# %% [markdown]
# # Preparing the experiment

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# We'll be training the model in a Federated setting. In order to do that, we need to define two functions:
#
# * `train()` that will train the model given a dataloader.
# * `test()` that will be used to evaluate the performance of the model on held-out data, e.g., a training set.

# %%
class Net(nn.Module): 
    def __init__(self, 
                 num_classes: int=8): # input_size = 46 number of features
        super(Net, self).__init__()
        self.lstm = nn.LSTM(
            input_size=46,
            hidden_size=32,
            bidirectional=True,
        )
       
        self.fc = nn.Linear(32 * 2, num_classes)

    def forward(self, x):
        x = x.transpose(0, 1) # (sequence_length, batch_size, input_size)
        r_out, (h_n, h_c) = self.lstm(x)
        r_out = r_out[-1]  
        model = self.fc(r_out) 
        return model

# %%
net = Net(num_classes=8)

# %%
print(net)
print(net.parameters)
total = sum([param.nelement() for param in net.parameters()])
print("Number of parameter: %.2fM" % (total / 1e6))
# Out:
# Net(
#   (lstm): LSTM(46, 32, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=8, bias=True)
# )
# <bound method Module.parameters of Net(
#   (lstm): LSTM(46, 32, bidirectional=True)
#   (fc): Linear(in_features=64, out_features=8, bias=True)
# )>
# Number of parameter: 0.02M

# %%
def train(net, trainloader, optimizer, epochs, device):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    net.train()
    net.to(device)

    for _ in range(epochs):
        for features, labels in trainloader:
            features, labels = features.to(device), labels.to(device)
            features = features.view(-1, 1, 46).float() # for transformation
            labels = labels.long() ######
            optimizer.zero_grad()
            outputs = net(features)
            outputs = outputs.float() ######
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
    return net


def test(net, testloader, device):
    """Validate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, loss = 0, 0.0

    predicts = []
    all_labels = []

    net.eval()
    net.to(device)
    with torch.no_grad():
        for features, labels in testloader:
            features, labels = features.to(device), labels.to(device)
            features = features.view(-1, 1, 46).float()
            labels = labels.long() ######
            outputs = net(features)
            outputs = outputs.float() ######
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()

            #####
            # for metrics   
            # Collect predictions and true labels for later use in calculating metrics
            predicts += predicted.tolist()
            all_labels += labels.cpu().numpy().tolist()
    # accuracy = correct / len(testloader.dataset)
    accuracy = accuracy_score(all_labels, predicts)
    precision = precision_score(all_labels, predicts, average='weighted', zero_division=1)
    recall = recall_score(all_labels, predicts, average='weighted', zero_division=1)
    f1 = f1_score(all_labels, predicts, average='weighted')
    
    return loss, accuracy, precision, recall, f1

# %%
import flwr as fl

# %% [markdown]
# Now let's defice our Flower Client class:

# %%
from collections import OrderedDict
from typing import Dict, List, Tuple

import torch
from flwr.common import NDArrays, Scalar


class FlowerClient(fl.client.NumPyClient):
    def __init__(self, trainloader, vallodaer) -> None:
        super().__init__()

        self.trainloader = trainloader
        self.valloader = vallodaer
        self.model = Net(num_classes=8)
        # Determine device
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)  # send model to device

    def set_parameters(self, parameters):
        """With the model paramters received from the server,
        overwrite the uninitialise model in this class with them."""

        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        # now replace the parameters
        self.model.load_state_dict(state_dict, strict=True)

    def get_parameters(self, config: Dict[str, Scalar]):
        """Extract all model parameters and conver them to a list of
        NumPy arryas. The server doesn't work with PyTorch/TF/etc."""
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def fit(self, parameters, config):
        """This method train the model using the parameters sent by the
        server on the dataset of this client. At then end, the parameters
        of the locally trained model are communicated back to the server"""

        # copy parameters sent by the server into client's local model
        self.set_parameters(parameters)

        # read from config
        lr, epochs = config["lr"], config["epochs"]

        # Define the optimizer
        # optim = torch.optim.SGD(self.model.parameters(), lr=lr, momentum=0.9)
        optim = torch.optim.Adam(self.model.parameters(), lr=lr)
        # do local training
        train(self.model, self.trainloader, optim, epochs=epochs, device=self.device)

        # return the model parameters to the server as well as extra info (number of training examples in this case)
        return self.get_parameters({}), len(self.trainloader), {}

    def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]):
        """Evaluate the model sent by the server on this client's
        local validation set. Then return performance metrics."""

        self.set_parameters(parameters)
        loss, accuracy, precision, recall, f1 = test(self.model, self.valloader, device=self.device)
        # send statistics back to the server
        return float(loss), len(self.valloader), {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

# %%
def get_evaluate_fn(testloader):
    """This is a function that returns a function. The returned
    function (i.e. `evaluate_fn`) will be executed by the strategy
    at the end of each round to evaluate the stat of the global
    model."""

    def evaluate_fn(server_round: int, parameters, config):
        """This function is executed by the strategy it will instantiate
        a model and replace its parameters with those from the global model.
        The, the model will be evaluate on the test set."""

        model = Net(num_classes=8)

        # Determine device
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        model.to(device)  # send model to device

        # set parameters to the model
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)

        # call test
        loss, accuracy, precision, recall, f1 = test(model, testloader, device)
        return loss, {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

    return evaluate_fn


# now we can define the strategy
# strategy = fl.server.strategy.FedAvg(
#     fraction_fit=0.1,
#     fraction_evaluate=0.1,
#     min_available_clients=100,
#     evaluate_fn=get_evaluate_fn(testloader), # Even this is not required
# )

# %%
from flwr.common import Metrics


def fit_config(server_round: int) -> Dict[str, Scalar]:
    """Return a configuration with static batch size and (local) epochs."""
    config = {
        "epochs": 1,  # Number of local epochs done by clients
        "lr": 0.008, #0.01,  # Learning rate to use by clients during fit()
    }
    return config


def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    """Aggregation function for (federated) evaluation metrics, i.e. those returned by
    the client's evaluate() method."""
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %% [markdown]
# Now we can define our strategy:

# %%
# strategy = fl.server.strategy.FedAvg(
#     fraction_fit=0.5,  # Sample 10% of available clients for training
#     fraction_evaluate=0.1,  # Sample 5% of available clients for evaluation
#     min_fit_clients=5,  # Never sample less than 10 clients for training
#     min_evaluate_clients=4,  # Never sample less than 5 clients for evaluation
#     min_available_clients=int(
#         7
#     ),  # Wait until at least 75 clients are available
#     on_fit_config_fn=fit_config,
#     evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
#     evaluate_fn=get_evaluate_fn(testloader),  # global evaluation function
# )

# доступны все
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1,  # Sample 10% of available clients for training
    fraction_evaluate=0.2,  # Sample 5% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=int(
        10
    ),  # Wait until at least 75 clients are available
    on_fit_config_fn=fit_config,
    evaluate_metrics_aggregation_fn=weighted_average,  # aggregates federated metrics
    evaluate_fn=get_evaluate_fn(testloader),  # global evaluation function
)

# %% [markdown]
# So far we have:
# * created the dataset partitions (one for each client)
# * defined the client class
# * decided on a strategy to use
#
# Now we just need to launch the Flower FL experiment... not so fast! just one final function: let's create another callback that the Simulation Engine will use in order to span VirtualClients. As you can see this is really simple: construct a FlowerClient object, assigning each their own data partition.

# %%
def generate_client_fn(trainloaders, valloaders):
    def client_fn(cid: str):
        """Returns a FlowerClient containing the cid-th data partition"""

        return FlowerClient(
            trainloader=trainloaders[int(cid)], vallodaer=valloaders[int(cid)]
        )

    return client_fn


client_fn_callback = generate_client_fn(trainloaders, validationloaders)

# %% [markdown]
# Now we are ready to launch the FL experiment using Flower simulation:

# %%
# With a dictionary, you tell Flower's VirtualClientEngine that each
# client needs exclusive access to these many resources in order to run
client_resources = {"num_cpus": 1, "num_gpus": 0.0}

history = fl.simulation.start_simulation(
    client_fn=client_fn_callback,  # a callback to construct a client
    num_clients=10,  # total number of clients in the experiment
    config=fl.server.ServerConfig(num_rounds=10),  # let's run for 10 rounds
    strategy=strategy,  # the strategy that will orchestrate the whole FL pipeline
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-12-06 00:14:18,463 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-12-06 00:14:20,330	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-12-06 00:14:21,219 | app.py:213 | Flower VCE: Ray initialized with resources: {'memory': 3425560167.0, 'node:127.0.0.1': 1.0, 'node:__internal_head__': 1.0, 'CPU': 8.0, 'object_store_memory': 1712780083.0}
# INFO flwr 2023-12-06 00:14:21,219 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2023-12-06 00:14:21,220 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-12-06 00:14:21,232 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO flwr 2023-12-06 00:14:21,233 | server.py:89 | Initializing global parameters
# INFO flwr 2023-12-06 00:14:21,233 | server.py:276 | Requesting initial parameters from one random client
# INFO flwr 2023-12-06 00:14:24,802 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2023-12-06 00:14:24,806 | server.py:91 | Evaluating initial parameters
# INFO flwr 2023-12-06 00:14:25,569 | server.py:94 | initial parameters (loss, other metrics): 1468.6796126365662, {'accuracy': 0.030604950406576712, 'precision': 0.46731957720833084, 'recall': 0.030604950406576712, 'f1': 0.055967857434487456}
# INFO flwr 2023-12-06 00:14:25,569 | server.py:104 | FL starting
# DEBUG flwr 2023-12-06 00:14:25,570 | server.py:222 | fit_round 1: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:14:30,271 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20784308224; capacity: 494384795648. Object creation will fail if spilling is required.
# ERROR flwr 2023-12-06 00:14:32,058 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-06 00:14:32,167 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-06 00:14:32,387 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-06 00:14:33,308 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-06 00:14:34,220 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-06 00:14:35,041 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-06 00:14:35,947 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-06 00:14:36,100 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# ERROR flwr 2023-12-06 00:14:37,428 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-06 00:14:37,430 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-06 00:14:40,366 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20141244416; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:14:48,955 | server.py:236 | fit_round 1 received 5 results and 5 failures
# WARNING flwr 2023-12-06 00:14:48,962 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# INFO flwr 2023-12-06 00:14:50,047 | server.py:125 | fit progress: (1, 143.94038872420788, {'accuracy': 0.9149651505674202, 'precision': 0.9119014658721256, 'recall': 0.9149651505674202, 'f1': 0.9105639018616372}, 24.47747541699937)
# DEBUG flwr 2023-12-06 00:14:50,048 | server.py:173 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:14:50,462 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20143308800; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:15:00,555 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20139413504; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:15:02,734 | server.py:187 | evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:15:02,736 | server.py:222 | fit_round 2: strategy sampled 10 clients (out of 10)
# ERROR flwr 2023-12-06 00:15:10,271 | ray_client_proxy.py:145 | Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 134, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 265, in submit_client_job
#     self.submit(actor_fn, job)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 243, in submit
#     future = fn(actor, client_fn, job_fn, cid)
#   File "/opt/homebrew/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_client_proxy.py", line 135, in <lambda>
#     lambda a, c_fn, j_fn, cid: a.run.remote(c_fn, j_fn, cid),
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 177, in invocation
#     return actor._actor_method_call(
#   File "/opt/homebrew/lib/python3.10/site-packages/ray/actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#   File "python/ray/_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python/ray/_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python/ray/_raylet.pyx", line 734, in ray._raylet.prepare_args_internal
#   File "python/ray/_raylet.pyx", line 2939, in ray._raylet.CoreWorker.put_serialized_object_and_increment_local_ref
#   File "python/ray/_raylet.pyx", line 2831, in ray._raylet.CoreWorker._create_put_buffer
#   File "python/ray/_raylet.pyx", line 396, in ray._raylet.check_status
# ray.exceptions.OutOfDiskError: Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
#
# ERROR flwr 2023-12-06 00:15:10,275 | ray_client_proxy.py:146 | Local disk is full
# The object cannot be created because the local object store is full and the local disk's utilization is over capacity (95% by default).Tip: Use `df` on this node to check disk usage and `ray memory` to check object store memory usage.
# (raylet) [2023-12-06 00:15:10,651 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20136243200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:15:20,741 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20156575744; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:15:30,822 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20155977728; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:15:33,430 | server.py:236 | fit_round 2 received 9 results and 1 failures
# INFO flwr 2023-12-06 00:15:34,232 | server.py:125 | fit progress: (2, 29.473903946345672, {'accuracy': 0.9858144937896524, 'precision': 0.9858909044204278, 'recall': 0.9858144937896524, 'f1': 0.9853966953655721}, 68.66287154200108)
# DEBUG flwr 2023-12-06 00:15:34,232 | server.py:173 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:15:40,910 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20153417728; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:15:42,774 | server.py:187 | evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:15:42,777 | server.py:222 | fit_round 3: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:15:50,995 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20152434688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:16:01,001 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20167770112; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:16:11,097 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20169945088; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:16:14,554 | server.py:236 | fit_round 3 received 10 results and 0 failures
# INFO flwr 2023-12-06 00:16:15,482 | server.py:125 | fit progress: (3, 23.681440665968694, {'accuracy': 0.9879032258064516, 'precision': 0.9878310636085815, 'recall': 0.9879032258064516, 'f1': 0.9873370190938553}, 109.91288991700276)
# DEBUG flwr 2023-12-06 00:16:15,483 | server.py:173 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:16:21,098 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20168626176; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:16:23,592 | server.py:187 | evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:16:23,594 | server.py:222 | fit_round 4: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:16:31,187 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20167933952; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:16:41,189 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20165644288; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:16:51,194 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20167106560; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:16:54,404 | server.py:236 | fit_round 4 received 10 results and 0 failures
# INFO flwr 2023-12-06 00:16:55,109 | server.py:125 | fit progress: (4, 22.049048852699343, {'accuracy': 0.9882383165043338, 'precision': 0.9884412866977854, 'recall': 0.9882383165043338, 'f1': 0.9878262894700546}, 149.54031537500123)
# DEBUG flwr 2023-12-06 00:16:55,109 | server.py:173 | evaluate_round 4: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:17:01,285 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20170555392; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:17:07,493 | server.py:187 | evaluate_round 4 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:17:07,495 | server.py:222 | fit_round 5: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:17:11,376 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20162752512; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:17:21,465 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21238915072; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:17:31,558 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21239148544; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:17:38,662 | server.py:236 | fit_round 5 received 10 results and 0 failures
# INFO flwr 2023-12-06 00:17:39,968 | server.py:125 | fit progress: (5, 20.624447281647008, {'accuracy': 0.9894111339469216, 'precision': 0.9894621727212786, 'recall': 0.9894111339469216, 'f1': 0.9889174071308976}, 194.3994121249998)
# DEBUG flwr 2023-12-06 00:17:39,969 | server.py:173 | evaluate_round 5: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:17:41,653 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21234548736; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:17:49,846 | server.py:187 | evaluate_round 5 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:17:49,848 | server.py:222 | fit_round 6: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:17:51,748 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21234278400; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:18:01,845 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21236248576; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:18:11,928 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21235503104; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:18:21,929 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21232484352; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:18:23,016 | server.py:236 | fit_round 6 received 10 results and 0 failures
# INFO flwr 2023-12-06 00:18:23,769 | server.py:125 | fit progress: (6, 20.89914677964407, {'accuracy': 0.9888749888303101, 'precision': 0.9889015061033644, 'recall': 0.9888749888303101, 'f1': 0.9882564151329153}, 238.20040283300114)
# DEBUG flwr 2023-12-06 00:18:23,769 | server.py:173 | evaluate_round 6: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:18:31,934 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22308495360; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:18:36,763 | server.py:187 | evaluate_round 6 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:18:36,767 | server.py:222 | fit_round 7: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:18:41,940 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21232889856; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:18:51,941 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21227450368; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:19:02,035 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21226782720; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:19:12,042 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21226266624; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:19:21,934 | server.py:236 | fit_round 7 received 10 results and 0 failures
# (raylet) [2023-12-06 00:19:22,057 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21224771584; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-06 00:19:25,281 | server.py:125 | fit progress: (7, 19.961726251320215, {'accuracy': 0.9895675096059333, 'precision': 0.9896715760145334, 'recall': 0.9895675096059333, 'f1': 0.9889926798444821}, 299.71257795800193)
# DEBUG flwr 2023-12-06 00:19:25,282 | server.py:173 | evaluate_round 7: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:19:32,093 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21217980416; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:19:41,427 | server.py:187 | evaluate_round 7 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:19:41,434 | server.py:222 | fit_round 8: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:19:42,185 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21217865728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:19:52,274 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21221601280; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:20:02,277 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21219454976; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:20:12,373 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21215858688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:20:22,473 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21221978112; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:20:23,296 | server.py:236 | fit_round 8 received 10 results and 0 failures
# INFO flwr 2023-12-06 00:20:24,191 | server.py:125 | fit progress: (8, 20.103944319998845, {'accuracy': 0.989422303636851, 'precision': 0.9894500376748633, 'recall': 0.989422303636851, 'f1': 0.9888595893082452}, 358.6231305420006)
# DEBUG flwr 2023-12-06 00:20:24,192 | server.py:173 | evaluate_round 8: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:20:32,573 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21220900864; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:20:33,382 | server.py:187 | evaluate_round 8 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:20:33,383 | server.py:222 | fit_round 9: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:20:42,672 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21224239104; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:20:52,688 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21224927232; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:21:02,786 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21221834752; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:21:12,789 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21220184064; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:21:21,264 | server.py:236 | fit_round 9 received 10 results and 0 failures
# (raylet) [2023-12-06 00:21:22,884 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21220024320; capacity: 494384795648. Object creation will fail if spilling is required.
# INFO flwr 2023-12-06 00:21:23,122 | server.py:125 | fit progress: (9, 19.09135889717436, {'accuracy': 0.9901148244124743, 'precision': 0.9900880945684728, 'recall': 0.9901148244124743, 'f1': 0.9896491253796877}, 417.5546302500006)
# DEBUG flwr 2023-12-06 00:21:23,123 | server.py:173 | evaluate_round 9: strategy sampled 5 clients (out of 10)
# DEBUG flwr 2023-12-06 00:21:32,561 | server.py:187 | evaluate_round 9 received 5 results and 0 failures
# DEBUG flwr 2023-12-06 00:21:32,575 | server.py:222 | fit_round 10: strategy sampled 10 clients (out of 10)
# (raylet) [2023-12-06 00:21:32,972 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 21211406336; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:21:43,054 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20133277696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:21:53,103 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20131287040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:22:03,114 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20129501184; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:22:13,129 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20132622336; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:22:23,225 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20135124992; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:22:25,674 | server.py:236 | fit_round 10 received 10 results and 0 failures
# INFO flwr 2023-12-06 00:22:26,810 | server.py:125 | fit progress: (10, 19.616324234637432, {'accuracy': 0.9900478062728979, 'precision': 0.9896872650195866, 'recall': 0.9900478062728979, 'f1': 0.9895345024571481}, 481.24249966700154)
# DEBUG flwr 2023-12-06 00:22:26,810 | server.py:173 | evaluate_round 10: strategy sampled 5 clients (out of 10)
# (raylet) [2023-12-06 00:22:33,322 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20131504128; capacity: 494384795648. Object creation will fail if spilling is required.
# DEBUG flwr 2023-12-06 00:22:39,075 | server.py:187 | evaluate_round 10 received 5 results and 0 failures
# INFO flwr 2023-12-06 00:22:39,077 | server.py:153 | FL finished in 493.50965991700286
# INFO flwr 2023-12-06 00:22:39,078 | app.py:226 | app_fit: losses_distributed [(1, 167.34411094460364), (2, 33.89868482583102), (3, 27.720983311539378), (4, 26.311642922594537), (5, 24.370147858829956), (6, 24.50330268216015), (7, 24.27861529646686), (8, 24.128836158492735), (9, 22.16605923532224), (10, 22.816711179136558)]
# INFO flwr 2023-12-06 00:22:39,078 | app.py:227 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-12-06 00:22:39,079 | app.py:228 | app_fit: metrics_distributed {'accuracy': [(1, 0.9152387233513836), (2, 0.9862703313613127), (3, 0.9881467819925663), (4, 0.9883151115618739), (5, 0.9891490599176046), (6, 0.9892411631889516), (7, 0.989667977524838), (8, 0.9892800618670827), (9, 0.9901674538119155), (10, 0.9898149176999139)]}
# INFO flwr 2023-12-06 00:22:39,079 | app.py:229 | app_fit: losses_centralized [(0, 1468.6796126365662), (1, 143.94038872420788), (2, 29.473903946345672), (3, 23.681440665968694), (4, 22.049048852699343), (5, 20.624447281647008), (6, 20.89914677964407), (7, 19.961726251320215), (8, 20.103944319998845), (9, 19.09135889717436), (10, 19.616324234637432)]
# INFO flwr 2023-12-06 00:22:39,079 | app.py:230 | app_fit: metrics_centralized {'accuracy': [(0, 0.030604950406576712), (1, 0.9149651505674202), (2, 0.9858144937896524), (3, 0.9879032258064516), (4, 0.9882383165043338), (5, 0.9894111339469216), (6, 0.9888749888303101), (7, 0.9895675096059333), (8, 0.989422303636851), (9, 0.9901148244124743), (10, 0.9900478062728979)], 'precision': [(0, 0.46731957720833084), (1, 0.9119014658721256), (2, 0.9858909044204278), (3, 0.9878310636085815), (4, 0.9884412866977854), (5, 0.9894621727212786), (6, 0.9889015061033644), (7, 0.9896715760145334), (8, 0.9894500376748633), (9, 0.9900880945684728), (10, 0.9896872650195866)], 'recall': [(0, 0.030604950406576712), (1, 0.9149651505674202), (2, 0.9858144937896524), (3, 0.9879032258064516), (4, 0.9882383165043338), (5, 0.9894111339469216), (6, 0.9888749888303101), (7, 0.9895675096059333), (8, 0.989422303636851), (9, 0.9901148244124743), (10, 0.9900478062728979)], 'f1': [(0, 0.055967857434487456), (1, 0.9105639018616372), (2, 0.9853966953655721), (3, 0.9873370190938553), (4, 0.9878262894700546), (5, 0.9889174071308976), (6, 0.9882564151329153), (7, 0.9889926798444821), (8, 0.9888595893082452), (9, 0.9896491253796877), (10, 0.9895345024571481)]}

# %%
from matplotlib import pyplot as plt


print(f"{history.metrics_centralized = }")

global_accuracy_centralised = history.metrics_centralized["accuracy"]
global_recall_centralised = history.metrics_centralized["recall"]
global_precision_centralised = history.metrics_centralized["precision"]
global_f1_centralised = history.metrics_centralized["f1"]


round = [data[0] for data in global_accuracy_centralised]
acc = [100.0 * data[1] for data in global_accuracy_centralised]
recall = [100.0 * data[1] for data in global_recall_centralised]
precision = [100.0 * data[1] for data in global_precision_centralised]
f1 = [100.0 * data[1] for data in global_f1_centralised]

plt.plot(round, acc, label='Accuracy')
plt.plot(round, recall, label='Recall')
plt.plot(round, f1, label='F1 Score')
plt.plot(round, precision, label='Precision')

plt.grid()
plt.xlabel('Round')
plt.ylabel('Percentage (%)')
plt.legend()
plt.show()
# Out:
# history.metrics_centralized = {'accuracy': [(0, 0.030604950406576712), (1, 0.9149651505674202), (2, 0.9858144937896524), (3, 0.9879032258064516), (4, 0.9882383165043338), (5, 0.9894111339469216), (6, 0.9888749888303101), (7, 0.9895675096059333), (8, 0.989422303636851), (9, 0.9901148244124743), (10, 0.9900478062728979)], 'precision': [(0, 0.46731957720833084), (1, 0.9119014658721256), (2, 0.9858909044204278), (3, 0.9878310636085815), (4, 0.9884412866977854), (5, 0.9894621727212786), (6, 0.9889015061033644), (7, 0.9896715760145334), (8, 0.9894500376748633), (9, 0.9900880945684728), (10, 0.9896872650195866)], 'recall': [(0, 0.030604950406576712), (1, 0.9149651505674202), (2, 0.9858144937896524), (3, 0.9879032258064516), (4, 0.9882383165043338), (5, 0.9894111339469216), (6, 0.9888749888303101), (7, 0.9895675096059333), (8, 0.989422303636851), (9, 0.9901148244124743), (10, 0.9900478062728979)], 'f1': [(0, 0.055967857434487456), (1, 0.9105639018616372), (2, 0.9853966953655721), (3, 0.9873370190938553), (4, 0.9878262894700546), (5, 0.9889174071308976), (6, 0.9882564151329153), (7, 0.9889926798444821), (8, 0.9888595893082452), (9, 0.9896491253796877), (10, 0.9895345024571481)]}
# (raylet) [2023-12-06 00:22:43,416 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20130852864; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:22:53,511 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20128612352; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:23:03,610 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20125876224; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:23:13,706 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20125143040; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:23:23,711 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20124745728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:23:33,805 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20122341376; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:23:43,902 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20118507520; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:23:53,999 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20118609920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:24:04,096 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20114960384; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:24:14,193 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20114595840; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:24:24,292 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20116987904; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:24:34,389 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20116013056; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:24:44,488 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 20118720512; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:24:54,489 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22263377920; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:25:04,586 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22270984192; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:25:14,687 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22271700992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:25:24,783 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22275891200; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:25:34,786 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22273531904; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:25:44,884 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22272073728; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:25:54,976 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22268829696; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:26:05,077 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22282506240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:26:15,172 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22281961472; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:26:25,178 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22284115968; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:26:35,276 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22282117120; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:26:45,276 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22275182592; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:26:55,370 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22272499712; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:27:05,374 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22271344640; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:27:15,472 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22269931520; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:27:25,570 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22268456960; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:27:35,669 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22267121664; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:27:45,697 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22266519552; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:27:55,794 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22265167872; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:28:05,887 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22260023296; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:28:15,888 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22263021568; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:28:25,985 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22260051968; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:28:36,074 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22257168384; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:28:46,171 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22256852992; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:28:56,270 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22253682688; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:29:06,365 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22252539904; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:29:16,463 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22251548672; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:29:26,562 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22249664512; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:29:36,566 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22248181760; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:29:46,663 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22254346240; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:29:56,764 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22254661632; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:30:06,860 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22252040192; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:30:16,958 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22251581440; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:30:26,961 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22261366784; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:30:37,060 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22259306496; capacity: 494384795648. Object creation will fail if spilling is required.
# (raylet) [2023-12-06 00:30:47,076 E 15047 803041] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-12-06_00-14-18_541342_14941 is over 95% full, available space: 22256865280; capacity: 494384795648. Object creation will fail if spilling is required.
